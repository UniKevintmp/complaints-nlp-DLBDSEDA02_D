# %%
# !pip -q install pandas numpy scikit-learn spacy gensim pyLDAvis tqdm sentence-transformers
# !python -m spacy download en_core_web_sm -q

# %%
import pandas as pd

df = pd.read_csv("rows.csv")

print("Form der Daten:", df.shape)
print("Spaltennamen:")
print(df.columns)

df.head()

# %%
text_col = "Consumer complaint narrative"

df = df[df[text_col].notna()].copy()
df = df[[text_col]].rename(columns={text_col: "text"})

print(df.shape)
df.head()
# Out:
# (315298, 1)
#                                                     text
# 29904  The Summer of XX/XX/2018 I was denied a mortga...
# 30629  There are many mistakes appear in my report wi...
# 30735  There are many mistakes appear in my report wi...
# 30795  There are many mistakes appear in my report wi...
# 30807  There are many mistakes appear in my report wi...

# %%
df = df.sample(10000, random_state=42)
print("Neue Größe:", df.shape)
# Out:
# Neue Größe: (10000, 1)

# %%
import re
import spacy
from tqdm import tqdm

nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])

def clean_to_tokens(text):
    text = text.lower()
    text = re.sub(r"http\S+|www\.\S+", " ", text)
    text = re.sub(r"[^a-z\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()

    doc = nlp(text)
    tokens = [
        t.lemma_ for t in doc
        if not t.is_stop and len(t.lemma_) > 2
    ]
    return tokens

tqdm.pandas()
df["tokens"] = df["text"].progress_apply(clean_to_tokens)
df["clean_text"] = df["tokens"].apply(lambda x: " ".join(x))

df[["text", "clean_text"]].head()
# Out:
# 100%|██████████| 10000/10000 [02:00<00:00, 82.83it/s]
#                                                      text  \
# 374887  I have a big problem with freedom mortgage im ...
# 302576  I pulled my credit on XXXX XXXX and saw a hard...
# 511776  I asked them if I could pay this debt or a set...
# 742168  XX/XX/XXXX/XX/XX/XXXX, I submitted an IBR re-r...
# 496043  1. My FCRA rights being violated by TransUnion...
#
#                                                clean_text
# 374887  big problem freedom mortgage try save home ask...
# 302576  pull credit xxxx xxxx see hard inquiry citi ba...
# 511776  ask pay debt settlement pay deletion say yes w...
# 742168  xxxx xxxx submit ibr request loan account loan...
# 496043  fcra right violate transunion transunion remov...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(
    max_df=0.9,
    min_df=5,
    ngram_range=(1,2)
)

X_tfidf = tfidf.fit_transform(df["clean_text"])

print("Form der TF-IDF Matrix:", X_tfidf.shape)
# Out:
# Form der TF-IDF Matrix: (10000, 26413)

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")
X_emb = model.encode(df["text"].tolist(), show_progress_bar=True)

print("Form der Embedding-Matrix:", X_emb.shape)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]
# Form der Embedding-Matrix: (10000, 384)

# %%
from gensim import corpora
from gensim.models import LdaModel, CoherenceModel

dictionary = corpora.Dictionary(df["tokens"])
corpus = [dictionary.doc2bow(toks) for toks in df["tokens"]]

def lda_coherence(k):
    lda = LdaModel(
        corpus=corpus,
        id2word=dictionary,
        num_topics=k,
        random_state=42,
        passes=10
    )
    coherence = CoherenceModel(
        model=lda,
        texts=df["tokens"],
        dictionary=dictionary,
        coherence="c_v"
    ).get_coherence()
    return lda, coherence

scores = []
models = {}

for k in range(5, 16):
    lda_model, score = lda_coherence(k)
    scores.append((k, score))
    models[k] = lda_model
    print(f"k={k}, coherence={score}")
# Out:
# k=5, coherence=0.4142737518407249
# k=6, coherence=0.4267637747803221
# k=7, coherence=0.4222401736075092
# k=8, coherence=0.451770008829862
# k=9, coherence=0.46617014977711363
# k=10, coherence=0.46157171990929224
# k=11, coherence=0.454492511271655
# k=12, coherence=0.4634602651756219
# k=13, coherence=0.4653480113158768
# k=14, coherence=0.47278265763032123
# k=15, coherence=0.4707527032113118

# %%
best_k = max(scores, key=lambda x: x[1])[0]
print("Bestes k laut Coherence:", best_k)
# Out:
# Bestes k laut Coherence: 14

# %%
lda = models[best_k]

for i, topic in lda.print_topics(num_topics=best_k, num_words=10):
    print(f"\nTopic {i}:")
    print(topic)
# Out:
# Topic 0:
# 0.061*"account" + 0.053*"report" + 0.052*"credit" + 0.034*"collection" + 0.028*"letter" + 0.026*"send" + 0.026*"debt" + 0.023*"company" + 0.021*"xxxx" + 0.018*"receive"
#
# Topic 1:
# 0.097*"payment" + 0.047*"loan" + 0.045*"pay" + 0.023*"month" + 0.021*"late" + 0.019*"xxxx" + 0.017*"interest" + 0.015*"balance" + 0.014*"time" + 0.013*"year"
#
# Topic 2:
# 0.032*"xxxx" + 0.022*"charge" + 0.022*"card" + 0.017*"account" + 0.016*"receive" + 0.012*"service" + 0.012*"fraud" + 0.011*"email" + 0.010*"customer" + 0.010*"purchase"
#
# Topic 3:
# 0.136*"car" + 0.091*"finance" + 0.085*"vehicle" + 0.058*"citibank" + 0.051*"lease" + 0.040*"auto" + 0.036*"purchase" + 0.026*"financial" + 0.022*"ally" + 0.022*"dealership"
#
# Topic 4:
# 0.228*"fargo" + 0.218*"wells" + 0.034*"pmi" + 0.013*"sale" + 0.013*"like" + 0.013*"well" + 0.013*"appraisal" + 0.011*"cash" + 0.011*"match" + 0.011*"copy"
#
# Topic 5:
# 0.182*"inquiry" + 0.097*"credit" + 0.065*"report" + 0.044*"remove" + 0.033*"authorize" + 0.031*"hard" + 0.028*"identity" + 0.026*"theft" + 0.025*"inquire" + 0.024*"unauthorized"
#
# Topic 6:
# 0.058*"account" + 0.058*"bank" + 0.028*"check" + 0.024*"money" + 0.022*"xxxx" + 0.014*"fee" + 0.014*"day" + 0.014*"tell" + 0.013*"fund" + 0.011*"close"
#
# Topic 7:
# 0.037*"consumer" + 0.025*"information" + 0.024*"law" + 0.022*"act" + 0.018*"provide" + 0.015*"violation" + 0.015*"reporting" + 0.014*"fair" + 0.013*"federal" + 0.013*"agency"
#
# Topic 8:
# 0.739*"xxxx" + 0.008*"account" + 0.007*"date" + 0.004*"credit" + 0.004*"address" + 0.003*"xxxxxxxx" + 0.003*"request" + 0.003*"report" + 0.003*"balance" + 0.003*"number"
#
# Topic 9:
# 0.054*"xxxx" + 0.030*"mortgage" + 0.028*"loan" + 0.016*"home" + 0.010*"property" + 0.010*"request" + 0.010*"document" + 0.009*"receive" + 0.009*"modification" + 0.008*"letter"
#
# Topic 10:
# 0.185*"debt" + 0.034*"collect" + 0.029*"collection" + 0.025*"creditor" + 0.025*"original" + 0.023*"owe" + 0.020*"collector" + 0.019*"claim" + 0.017*"proof" + 0.016*"contract"
#
# Topic 11:
# 0.049*"call" + 0.039*"tell" + 0.027*"say" + 0.024*"ask" + 0.023*"xxxx" + 0.022*"phone" + 0.019*"time" + 0.019*"number" + 0.016*"speak" + 0.015*"contact"
#
# Topic 12:
# 0.125*"credit" + 0.078*"card" + 0.027*"score" + 0.016*"capital" + 0.015*"account" + 0.014*"close" + 0.013*"year" + 0.009*"point" + 0.009*"xxxx" + 0.009*"apply"
#
# Topic 13:
# 0.074*"report" + 0.062*"credit" + 0.045*"account" + 0.036*"information" + 0.026*"dispute" + 0.020*"equifax" + 0.019*"file" + 0.018*"xxxx" + 0.016*"verify" + 0.016*"remove"

# %%
from sklearn.cluster import KMeans

k2 = 8

kmeans = KMeans(n_clusters=k2, random_state=42, n_init="auto")
clusters = kmeans.fit_predict(X_emb)

df["cluster"] = clusters

df["cluster"].value_counts().sort_index()
# Out:
# cluster
# 0    1259
# 1     944
# 2    1411
# 3    1130
# 4    1475
# 5    1853
# 6    1350
# 7     578
# Name: count, dtype: int64

# %%
for c in range(k2):
    print("\nCLUSTER", c)
    sample_texts = df[df["cluster"] == c]["text"].head(3).tolist()
    for t in sample_texts:
        print("-", t[:200].replace("\n"," "), "...")
# Out:
# CLUSTER 0
# - I opened an auto loan with XXXX XXXX in XX/XX/XXXX.  XXXX XXXX XXXX XXXX XXXX XXXX XXXX, XXXX, CA XXXX I paid every month and was not late once, EVER. As of this year I filed bankruptcy on XX/XX/XXXX  ...
# - I was reading my credit report from XXXX and found that my credit score is affected by an account of a credit card that is not mine. The account is now closed, the balance is higher that the credit li ...
# - My BLOOMINGDALES credit card account had a {$420.00} credit that was stolen evidently by a Bloomingdale employee. I 've contacted customer service and had no results.  We were in XXXX XXXX XXXX/XXXX/X ...
#
# CLUSTER 1
# - I accepted a loan from AvailBlue for {$350.00}. I was told when they would drafting the first payment, amounts etc. Prior to accepting the loan I spoke with the Agent and asked him about early pay off ...
# - I attended to XXXX college for six months.. XXXX made me take out a private loan called American student financial group ; direct lending program ... of XXXX, to found out tow months later when the sc ...
# - In XX/XX/XXXX, I began XXXX school to work on a XXXX XXXX Degree. I completed the coursework in XX/XX/XXXX and began focusing on writing my thesis in XX/XX/XXXX. I was enrolled at XXXX ( XXXX ) for th ...
#
# CLUSTER 2
# - I pulled my credit on XXXX XXXX and saw a hard inquiry from Citi Bank on XX/XX/XXXX who I have nor do I use and have never authorized a request for credit. There is no number to contact anyone and rea ...
# - 1. My FCRA rights being violated by TransUnion. 2. Part One- TransUnion removed my inaccurate hard inquiry 's ( good ) Part Two- Transunion added the inquiry 's back onto my credit report without the  ...
# - Checked   XXXX   XXXX   and there is a hard inquiry from  XXXX  ( Retail, Not Elsewhere Classified ) on  XXXX   XXXX ,  2017 . I never authorized a credit check for anybody in the past   XXXX   years. ...
#
# CLUSTER 3
# - I initially opened my bank account XX/XX/XXXXfor my VA XXXX check as the government wanted to do away with a paper check. My account did not have any service fees attached to it as long as I used no c ...
# - The bank opened my account TWO Days ago yesterday I was able to put money into the account but today I can not remove it ...
# - Currently on XXXX XXXX I had a banking issue which ended up cancelling and refunding a out I had made through coinbase. They locked down my account due to it and asked for a resent payment which I gla ...
#
# CLUSTER 4
# - I asked them if I could pay this debt or a settlement would they do a pay for deletion. They said yes. They did not keep there word. I paid this debt and they said they would delete it from my credit  ...
# - I had XXXX XXXX internet service about 4 years ago, for literally less than two weeks. The service was not as promised, so we canceled it right away. Since then, I have been contacted by a number of d ...
# - Collection agencies ( XXXX XXXX XXXX XXXX ) have added a collection to all three credit bureaus and I do not owe the original creditor who is XXXX XXXX. My insurance paid the balance many years ago an ...
#
# CLUSTER 5
# - I have written XXXX letters to each of the reporting credit bureaus requesting any and all documentation bearing my signature of a Bankruptcy reporting under my social security number. I also requeste ...
# - I have an  XXXX  credit card with  XXXX    XXXX   and in  XXXX  my credit limit was increased from {$300.00} to {$1000.00} and the credit limit increase has not been reflected correctly with  XXXX  or ...
# - My credit report has been perfect for over 10 years. Out of no where I got 2 collections : Opened XX/XX/XXXX ( 3 mos ) by XXXX Amount : {$74.00} XXXX XXXX XXXX XXXX XXXX XXXX XXXX, FL XXXX +++ Opened  ...
#
# CLUSTER 6
# - I have a big problem with freedom mortgage im trying to save my home I asked for help from them with a modification I am complying with everything they asked I even have a hud counselar working with m ...
# - XX/XX/XXXX/XX/XX/XXXX, I submitted an IBR re-request on my loan accounts. I have several loans through various servicers. ACS is the only one that requires me to submit paper documentation and to fill ...
# - My home mortgage account was with XXXX Bank and it was sold to LoanCare XXXX. I recieved a notice from XXXX bank about a month and a half ago informing me of this. I have not received any corresponden ...
#
# CLUSTER 7
# - I informed them that I am unable to pay back the amount at the moment and I can no longer receive personal calls at my place of employment and they continue to call me at work and are jeopardizing my  ...
# - In several occasions including XX/XX/18, a representative named XXXX, has contacted me via telephone while at work. She has been very rude with insults, profanities, and threats. While attempting to r ...
# - I was speaking with someone from Mariner Finance on XX/XX/XXXX, who stated that I need to make a payment on XX/XX/XXXX. I informed them that I would call in on XX/XX/XXXX to make that payment. On XX/X ...

# %%
lda = models[14]

for i, topic in lda.print_topics(num_topics=14, num_words=10):
    print(f"\nTopic {i}:")
    print(topic)
# Out:
# Topic 0:
# 0.061*"account" + 0.053*"report" + 0.052*"credit" + 0.034*"collection" + 0.028*"letter" + 0.026*"send" + 0.026*"debt" + 0.023*"company" + 0.021*"xxxx" + 0.018*"receive"
#
# Topic 1:
# 0.097*"payment" + 0.047*"loan" + 0.045*"pay" + 0.023*"month" + 0.021*"late" + 0.019*"xxxx" + 0.017*"interest" + 0.015*"balance" + 0.014*"time" + 0.013*"year"
#
# Topic 2:
# 0.032*"xxxx" + 0.022*"charge" + 0.022*"card" + 0.017*"account" + 0.016*"receive" + 0.012*"service" + 0.012*"fraud" + 0.011*"email" + 0.010*"customer" + 0.010*"purchase"
#
# Topic 3:
# 0.136*"car" + 0.091*"finance" + 0.085*"vehicle" + 0.058*"citibank" + 0.051*"lease" + 0.040*"auto" + 0.036*"purchase" + 0.026*"financial" + 0.022*"ally" + 0.022*"dealership"
#
# Topic 4:
# 0.228*"fargo" + 0.218*"wells" + 0.034*"pmi" + 0.013*"sale" + 0.013*"like" + 0.013*"well" + 0.013*"appraisal" + 0.011*"cash" + 0.011*"match" + 0.011*"copy"
#
# Topic 5:
# 0.182*"inquiry" + 0.097*"credit" + 0.065*"report" + 0.044*"remove" + 0.033*"authorize" + 0.031*"hard" + 0.028*"identity" + 0.026*"theft" + 0.025*"inquire" + 0.024*"unauthorized"
#
# Topic 6:
# 0.058*"account" + 0.058*"bank" + 0.028*"check" + 0.024*"money" + 0.022*"xxxx" + 0.014*"fee" + 0.014*"day" + 0.014*"tell" + 0.013*"fund" + 0.011*"close"
#
# Topic 7:
# 0.037*"consumer" + 0.025*"information" + 0.024*"law" + 0.022*"act" + 0.018*"provide" + 0.015*"violation" + 0.015*"reporting" + 0.014*"fair" + 0.013*"federal" + 0.013*"agency"
#
# Topic 8:
# 0.739*"xxxx" + 0.008*"account" + 0.007*"date" + 0.004*"credit" + 0.004*"address" + 0.003*"xxxxxxxx" + 0.003*"request" + 0.003*"report" + 0.003*"balance" + 0.003*"number"
#
# Topic 9:
# 0.054*"xxxx" + 0.030*"mortgage" + 0.028*"loan" + 0.016*"home" + 0.010*"property" + 0.010*"request" + 0.010*"document" + 0.009*"receive" + 0.009*"modification" + 0.008*"letter"
#
# Topic 10:
# 0.185*"debt" + 0.034*"collect" + 0.029*"collection" + 0.025*"creditor" + 0.025*"original" + 0.023*"owe" + 0.020*"collector" + 0.019*"claim" + 0.017*"proof" + 0.016*"contract"
#
# Topic 11:
# 0.049*"call" + 0.039*"tell" + 0.027*"say" + 0.024*"ask" + 0.023*"xxxx" + 0.022*"phone" + 0.019*"time" + 0.019*"number" + 0.016*"speak" + 0.015*"contact"
#
# Topic 12:
# 0.125*"credit" + 0.078*"card" + 0.027*"score" + 0.016*"capital" + 0.015*"account" + 0.014*"close" + 0.013*"year" + 0.009*"point" + 0.009*"xxxx" + 0.009*"apply"
#
# Topic 13:
# 0.074*"report" + 0.062*"credit" + 0.045*"account" + 0.036*"information" + 0.026*"dispute" + 0.020*"equifax" + 0.019*"file" + 0.018*"xxxx" + 0.016*"verify" + 0.016*"remove"

# %%
for k in [10, 11, 12]:
    lda = models[k]
    print("\n==== k =", k, "====")
    for i, topic in lda.print_topics(num_topics=k, num_words=6):
        print(i, topic)
# Out:
# ==== k = 10 ====
# 0 0.082*"credit" + 0.075*"report" + 0.059*"account" + 0.024*"dispute" + 0.021*"remove" + 0.018*"xxxx"
# 1 0.088*"payment" + 0.045*"loan" + 0.042*"pay" + 0.021*"month" + 0.021*"late" + 0.017*"xxxx"
# 2 0.048*"account" + 0.048*"card" + 0.027*"credit" + 0.026*"bank" + 0.023*"xxxx" + 0.023*"charge"
# 3 0.100*"car" + 0.062*"vehicle" + 0.045*"citibank" + 0.037*"lease" + 0.034*"bonus" + 0.032*"purchase"
# 4 0.063*"information" + 0.036*"equifax" + 0.033*"identity" + 0.032*"report" + 0.032*"bankruptcy" + 0.028*"theft"
# 5 0.212*"inquiry" + 0.119*"credit" + 0.046*"report" + 0.041*"hard" + 0.035*"authorize" + 0.032*"remove"
# 6 0.034*"xxxx" + 0.032*"call" + 0.029*"tell" + 0.020*"say" + 0.016*"ask" + 0.015*"time"
# 7 0.046*"debt" + 0.019*"consumer" + 0.017*"law" + 0.017*"provide" + 0.014*"collection" + 0.014*"information"
# 8 0.730*"xxxx" + 0.009*"account" + 0.008*"date" + 0.005*"credit" + 0.004*"address" + 0.004*"request"
# 9 0.054*"xxxx" + 0.029*"mortgage" + 0.026*"loan" + 0.015*"home" + 0.010*"fargo" + 0.010*"property"
#
# ==== k = 11 ====
# 0 0.086*"credit" + 0.082*"report" + 0.058*"account" + 0.024*"dispute" + 0.021*"remove" + 0.020*"information"
# 1 0.087*"payment" + 0.044*"loan" + 0.041*"pay" + 0.021*"month" + 0.021*"late" + 0.016*"xxxx"
# 2 0.050*"card" + 0.047*"account" + 0.029*"credit" + 0.024*"bank" + 0.024*"xxxx" + 0.023*"charge"
# 3 0.051*"american" + 0.041*"citibank" + 0.040*"offer" + 0.040*"express" + 0.031*"bonus" + 0.028*"equifax"
# 4 0.073*"address" + 0.066*"number" + 0.056*"information" + 0.046*"security" + 0.030*"social" + 0.018*"personal"
# 5 0.218*"inquiry" + 0.113*"credit" + 0.043*"report" + 0.043*"hard" + 0.038*"authorize" + 0.037*"remove"
# 6 0.033*"xxxx" + 0.033*"call" + 0.029*"tell" + 0.021*"say" + 0.016*"ask" + 0.015*"time"
# 7 0.026*"consumer" + 0.023*"information" + 0.020*"law" + 0.018*"provide" + 0.016*"request" + 0.015*"act"
# 8 0.732*"xxxx" + 0.008*"account" + 0.008*"date" + 0.005*"credit" + 0.003*"xxxxxxxx" + 0.003*"request"
# 9 0.056*"xxxx" + 0.028*"mortgage" + 0.026*"loan" + 0.015*"home" + 0.010*"fargo" + 0.009*"property"
# 10 0.190*"debt" + 0.083*"collection" + 0.042*"owe" + 0.028*"collect" + 0.025*"company" + 0.023*"agency"
#
# ==== k = 12 ====
# 0 0.099*"credit" + 0.090*"report" + 0.067*"account" + 0.023*"dispute" + 0.022*"remove" + 0.021*"xxxx"
# 1 0.090*"payment" + 0.045*"loan" + 0.042*"pay" + 0.022*"month" + 0.021*"late" + 0.018*"xxxx"
# 2 0.058*"card" + 0.032*"credit" + 0.025*"xxxx" + 0.022*"charge" + 0.016*"account" + 0.014*"receive"
# 3 0.106*"car" + 0.066*"vehicle" + 0.040*"lease" + 0.037*"breach" + 0.028*"financial" + 0.023*"finance"
# 4 0.071*"information" + 0.035*"file" + 0.034*"bankruptcy" + 0.032*"verify" + 0.029*"equifax" + 0.025*"report"
# 5 0.259*"inquiry" + 0.098*"credit" + 0.050*"hard" + 0.049*"authorize" + 0.039*"remove" + 0.037*"inquire"
# 6 0.053*"account" + 0.046*"bank" + 0.027*"xxxx" + 0.024*"check" + 0.021*"money" + 0.017*"tell"
# 7 0.028*"consumer" + 0.023*"law" + 0.022*"debt" + 0.016*"act" + 0.015*"agency" + 0.014*"information"
# 8 0.728*"xxxx" + 0.007*"date" + 0.006*"account" + 0.005*"credit" + 0.003*"xxxxxxxx" + 0.003*"request"
# 9 0.052*"xxxx" + 0.030*"mortgage" + 0.028*"loan" + 0.016*"home" + 0.010*"property" + 0.009*"receive"
# 10 0.101*"debt" + 0.042*"letter" + 0.036*"send" + 0.031*"proof" + 0.029*"collection" + 0.029*"request"
# 11 0.044*"call" + 0.033*"tell" + 0.025*"say" + 0.021*"phone" + 0.021*"ask" + 0.019*"time"

# %%
import re
import spacy
from tqdm import tqdm

nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])

def clean_to_tokens(text):
    text = text.lower()
    text = re.sub(r"http\S+|www\.\S+", " ", text)
    text = re.sub(r"[^a-z\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()

    doc = nlp(text)

    custom_stopwords = {"xxxx", "xxxxxxxx"}

    tokens = [
        t.lemma_ for t in doc
        if not t.is_stop
        and len(t.lemma_) > 2
        and t.lemma_ not in custom_stopwords
    ]

    return tokens

tqdm.pandas()
df["tokens"] = df["text"].progress_apply(clean_to_tokens)
df["clean_text"] = df["tokens"].apply(lambda x: " ".join(x))
# Out:
# 100%|██████████| 10000/10000 [02:25<00:00, 68.71it/s]

# %%
from gensim import corpora

# Dictionary neu erstellen
dictionary = corpora.Dictionary(df["tokens"])

# Bag-of-Words Corpus erstellen
corpus = [dictionary.doc2bow(toks) for toks in df["tokens"]]

print("Anzahl einzigartiger Wörter:", len(dictionary))
# Out:
# Anzahl einzigartiger Wörter: 13883

# %%
from gensim.models import LdaModel, CoherenceModel

def compute_coherence_values(start=11, limit=14):
    models = {}
    scores = []

    for k in range(start, limit):
        lda_model = LdaModel(
            corpus=corpus,
            id2word=dictionary,
            num_topics=k,
            random_state=42,
            passes=10
        )

        coherence_model = CoherenceModel(
            model=lda_model,
            texts=df["tokens"],
            dictionary=dictionary,
            coherence='c_v'
        )

        coherence_score = coherence_model.get_coherence()

        models[k] = lda_model
        scores.append((k, coherence_score))

        print(f"k={k}, coherence={coherence_score}")

    return models, scores

models, scores = compute_coherence_values()
# Out:
# k=11, coherence=0.47930440681546693
# k=12, coherence=0.4491337823837361
# k=13, coherence=0.46998513378014006

# %%
best_k = max(scores, key=lambda x: x[1])[0]
print("Bestes k laut Coherence:", best_k)

# %%
lda = models[11]

for i, topic in lda.print_topics(num_topics=11, num_words=8):
    print(f"\nTopic {i}:")
    print(topic)
# Out:
# Topic 0:
# 0.101*"report" + 0.099*"credit" + 0.070*"account" + 0.031*"remove" + 0.022*"dispute" + 0.015*"information" + 0.013*"file" + 0.011*"show"
#
# Topic 1:
# 0.083*"payment" + 0.052*"loan" + 0.039*"pay" + 0.020*"month" + 0.016*"interest" + 0.015*"year" + 0.014*"late" + 0.013*"time"
#
# Topic 2:
# 0.072*"credit" + 0.070*"card" + 0.035*"inquiry" + 0.025*"account" + 0.010*"charge" + 0.009*"chase" + 0.009*"capital" + 0.008*"score"
#
# Topic 3:
# 0.043*"call" + 0.040*"tell" + 0.028*"say" + 0.024*"ask" + 0.020*"time" + 0.019*"phone" + 0.016*"send" + 0.015*"speak"
#
# Topic 4:
# 0.045*"mortgage" + 0.033*"loan" + 0.030*"home" + 0.020*"property" + 0.018*"modification" + 0.015*"request" + 0.014*"sale" + 0.012*"document"
#
# Topic 5:
# 0.096*"debt" + 0.047*"collection" + 0.025*"owe" + 0.024*"company" + 0.020*"pay" + 0.018*"letter" + 0.018*"receive" + 0.017*"send"
#
# Topic 6:
# 0.018*"court" + 0.016*"complaint" + 0.015*"file" + 0.013*"case" + 0.012*"law" + 0.012*"document" + 0.010*"claim" + 0.010*"attorney"
#
# Topic 7:
# 0.030*"charge" + 0.022*"service" + 0.019*"receive" + 0.017*"email" + 0.014*"customer" + 0.011*"issue" + 0.011*"statement" + 0.010*"claim"
#
# Topic 8:
# 0.051*"fargo" + 0.048*"wells" + 0.047*"identity" + 0.045*"fraud" + 0.042*"theft" + 0.027*"fraudulent" + 0.024*"police" + 0.021*"victim"
#
# Topic 9:
# 0.039*"information" + 0.028*"credit" + 0.026*"request" + 0.024*"report" + 0.023*"account" + 0.021*"provide" + 0.020*"consumer" + 0.018*"verify"
#
# Topic 10:
# 0.076*"account" + 0.075*"bank" + 0.029*"check" + 0.028*"money" + 0.017*"fund" + 0.015*"fee" + 0.013*"deposit" + 0.013*"close"

# %%
df["cluster"].value_counts().sort_index()
# Out:
# cluster
# 0    1259
# 1     944
# 2    1411
# 3    1130
# 4    1475
# 5    1853
# 6    1350
# 7     578
# Name: count, dtype: int64

# %%
for c in sorted(df["cluster"].unique()):
    print("\n====================")
    print("CLUSTER", c)
    print("====================")

    sample_texts = df[df["cluster"] == c]["text"].head(2).tolist()

    for t in sample_texts:
        print("-", t[:300].replace("\n", " "), "...\n")
# Out:
# ====================
# CLUSTER 0
# ====================
# - I opened an auto loan with XXXX XXXX in XX/XX/XXXX.  XXXX XXXX XXXX XXXX XXXX XXXX XXXX, XXXX, CA XXXX I paid every month and was not late once, EVER. As of this year I filed bankruptcy on XX/XX/XXXX Due to the issues I continually had with the car, my lawyer and myself thought it would be best if I ...
#
# - I was reading my credit report from XXXX and found that my credit score is affected by an account of a credit card that is not mine. The account is now closed, the balance is higher that the credit limit, the account does n't receive a payment since may and my credit is suffering. It says that I am  ...
#
#
# ====================
# CLUSTER 1
# ====================
# - I accepted a loan from AvailBlue for {$350.00}. I was told when they would drafting the first payment, amounts etc. Prior to accepting the loan I spoke with the Agent and asked him about early pay off. He told me I could in fact pay the loan off early and just paying a small amount above the {$350.0 ...
#
# - I attended to XXXX college for six months.. XXXX made me take out a private loan called American student financial group ; direct lending program ... of XXXX, to found out tow months later when the school closed without previous notice, when I did my financial aid that I did n't needed it because I  ...
#
#
# ====================
# CLUSTER 2
# ====================
# - I pulled my credit on XXXX XXXX and saw a hard inquiry from Citi Bank on XX/XX/XXXX who I have nor do I use and have never authorized a request for credit. There is no number to contact anyone and really would like to find out how to have this removed.  Also on XX/XX/XXXX XXXX XXXX also pulled a har ...
#
# - 1. My FCRA rights being violated by TransUnion. 2. Part One- TransUnion removed my inaccurate hard inquiry 's ( good ) Part Two- Transunion added the inquiry 's back onto my credit report without the 5-Day notification required by FCRA. 3. Contacted TransUnion three times my mail, twice by phone and ...
#
#
# ====================
# CLUSTER 3
# ====================
# - I initially opened my bank account XX/XX/XXXXfor my VA XXXX check as the government wanted to do away with a paper check. My account did not have any service fees attached to it as long as I used no checked and never went into the bank and only used the debit card and the ATM. Wachovia bought this b ...
#
# - The bank opened my account TWO Days ago yesterday I was able to put money into the account but today I can not remove it ...
#
#
# ====================
# CLUSTER 4
# ====================
# - I asked them if I could pay this debt or a settlement would they do a pay for deletion. They said yes. They did not keep there word. I paid this debt and they said they would delete it from my credit report. All  XXXX  bureaus. It 's still reporting on my credit report. The account was paid. I then  ...
#
# - I had XXXX XXXX internet service about 4 years ago, for literally less than two weeks. The service was not as promised, so we canceled it right away. Since then, I have been contacted by a number of different collection agencies regarding a bill of {$690.00}. I have disputed the amount and collectio ...
#
#
# ====================
# CLUSTER 5
# ====================
# - I have written XXXX letters to each of the reporting credit bureaus requesting any and all documentation bearing my signature of a Bankruptcy reporting under my social security number. I also requested the name, address and telephone number of each person they contacted regarding this alleged claim. ...
#
# - I have an  XXXX  credit card with  XXXX    XXXX   and in  XXXX  my credit limit was increased from {$300.00} to {$1000.00} and the credit limit increase has not been reflected correctly with  XXXX  or Equifax fast the past few months. I have called  XXXX   XXXX  for the past 2 months and they told m ...
#
#
# ====================
# CLUSTER 6
# ====================
# - I have a big problem with freedom mortgage im trying to save my home I asked for help from them with a modification I am complying with everything they asked I even have a hud counselar working with me they stated I have something on my title that was about 6 or 8 years ago I was not living in the h ...
#
# - XX/XX/XXXX/XX/XX/XXXX, I submitted an IBR re-request on my loan accounts. I have several loans through various servicers. ACS is the only one that requires me to submit paper documentation and to fill out forms and fax thing to them. All of my other loans allow me to access the Federal Financial Aid ...
#
#
# ====================
# CLUSTER 7
# ====================
# - I informed them that I am unable to pay back the amount at the moment and I can no longer receive personal calls at my place of employment and they continue to call me at work and are jeopardizing my employment. On XX/XX/2019 at XXXX XXXX  they called my place of employment and asked to speak to my  ...
#
# - In several occasions including XX/XX/18, a representative named XXXX, has contacted me via telephone while at work. She has been very rude with insults, profanities, and threats. While attempting to resolve the default situation with XXXX, I have asked XXXX for her superiors contact information to r ...
